# %% [markdown]
# # 207 Course Schedule
# - given an array of pairs of prereqs, [(a, b)], course b must be taken before course A
# - return a boolean to indicate if you can finish all the courses in the required order
# ![image.png](attachment:image.png)

# %%
def can_finish(num_courses, prereqs):
    taken = set()
    reqs = {}
