# %% [markdown]
# https://leetcode.com/problems/container-with-most-water/
#
# return the maximum amount of water that could be stored between two lines from a list of line heights
#
# ![image.png](attachment:image.png)

# %%
test = [1,8,6,2,5,4,8,3,7]

# %%
def max_area(heights):
    left = 0
    right = len(heights) - 1
